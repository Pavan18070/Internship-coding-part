# %%
#importing the packages  
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
#import the dataset
data = pd.read_csv('/content/car data.csv')
data1 = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
data2 = pd.read_csv('/content/Car details v3.csv')
data3 = pd.read_csv('/content/car details v4.csv')

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
corr_matrix = data.corr()

# %%
print(corr_matrix)
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
data['Selling_Price'] = data['Selling_Price'] * 100000
data['Present_Price'] = data['Present_Price'] * 100000

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       335000.0       559000.0       27000    Petrol
# 1      sx4  2013       475000.0       954000.0       43000    Diesel
# 2     ciaz  2017       725000.0       985000.0        6900    Petrol
# 3  wagon r  2011       285000.0       415000.0        5200    Petrol
# 4    swift  2014       460000.0       687000.0       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data1.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
mapping = {}
for i, category in enumerate(data1['owner'].unique()):
    mapping[category] = i

data1['owner'] = data1['owner'].map(mapping)

# %%
data1.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission  owner
# 0  Individual       Manual      0
# 1  Individual       Manual      0
# 2  Individual       Manual      0
# 3  Individual       Manual      0
# 4  Individual       Manual      1

# %%
data2.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data2.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission  owner     mileage   engine  max_power  \
# 8123  Individual       Manual      0   18.5 kmpl  1197 CC  82.85 bhp
# 8124  Individual       Manual      3   16.8 kmpl  1493 CC    110 bhp
# 8125  Individual       Manual      0   19.3 kmpl  1248 CC   73.9 bhp
# 8126  Individual       Manual      0  23.57 kmpl  1396 CC     70 bhp
# 8127  Individual       Manual      0  23.57 kmpl  1396 CC     70 bhp
#
#                          torque  seats
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# ...

# %%
mapping = {}
for i, category in enumerate(data2['owner'].unique()):
    mapping[category] = i

data2['owner'] = data2['owner'].map(mapping)

# %%
data2.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission  owner     mileage   engine   max_power  \
# 0  Individual       Manual      0   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual      1  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual      2   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual      0   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual      0   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
data2.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission  owner     mileage   engine  max_power  \
# 8123  Individual       Manual      0   18.5 kmpl  1197 CC  82.85 bhp
# 8124  Individual       Manual      3   16.8 kmpl  1493 CC    110 bhp
# 8125  Individual       Manual      0   19.3 kmpl  1248 CC   73.9 bhp
# 8126  Individual       Manual      0  23.57 kmpl  1396 CC     70 bhp
# 8127  Individual       Manual      0  23.57 kmpl  1396 CC     70 bhp
#
#                          torque  seats
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# ...

# %%
data3.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
mapping = {}
for i, category in enumerate(data3['Owner'].unique()):
    mapping[category] = i

data3['Owner'] = data3['Owner'].map(mapping)

# %%
data3.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color  Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey      0   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White      1  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon      0  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red      0  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey      0  Individual  2393 cc
#
#             Max Power              Max Torque Drivetrain  Length   Width  \
# ...

# %%
data3.tail()
# Out:
#           Make                                  Model    Price  Year  \
# 2054  Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055   Hyundai                           Eon D-Lite +   275000  2014
# 2056      Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057       BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058  Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color  Owner Seller Type  \
# 2054      90300    Diesel       Manual       Surat   White      0  Individual
# 2055      83000    Petrol       Manual   Ahmedabad   White      1  Individual
# 2056      73000    Petrol       Manual       Thane  Silver      0  Individual
# 2057      60474    Diesel    Automatic  Coimbatore   White      0  Individual
# 2058      72000    Diesel       Manual    Guwahati   White      0  Individual
#
#        Engine           Max Power         Max Torque Drivetrain  Length  \
# ...

# %%
data1.rename(columns={'year': 'Year'}, inplace=True)
data2.rename(columns={'year': 'Year'}, inplace=True)
data1.rename(columns={'selling_price': 'Selling_Price'}, inplace=True)
data2.rename(columns={'selling_price': 'Selling_Price'}, inplace=True)
data3.rename(columns={'Price': 'Selling_Price'}, inplace=True)
data1.rename(columns={'fuel': 'Fuel_Type'}, inplace=True)
data2.rename(columns={'fuel': 'Fuel_Type'}, inplace=True)
data3.rename(columns={'Fuel Type': 'Fuel_Type'}, inplace=True)
data1.rename(columns={'transmission': 'Transmission'}, inplace=True)
data2.rename(columns={'transmission': 'Transmission'}, inplace=True)
data1.rename(columns={'seller_type': 'Seller_Type'}, inplace=True)
data2.rename(columns={'seller_type': 'Seller_Type'}, inplace=True)
data3.rename(columns={'Seller Type': 'Seller_Type'}, inplace=True)
data1.rename(columns={'name': 'Car_Name'}, inplace=True)
data2.rename(columns={'name': 'Car_Name'}, inplace=True)
data1.rename(columns={'km_driven': 'Kms_Driven'}, inplace=True)
data2.rename(columns={'km_driven': 'Kms_Driven'}, inplace=True)
data3.rename(columns={'Kilometer': 'Kms_Driven'}, inplace=True)
data.rename(columns={'Owner': 'owner'}, inplace=True)
data3.rename(columns={'Owner': 'owner'}, inplace=True)
data3.rename(columns={'Seating Capacity': 'seats'}, inplace=True)
data2.rename(columns={'engine': 'Engine'}, inplace=True)
data2.rename(columns={'torque': 'Max_Torque'}, inplace=True)
data3.rename(columns={'Max Torque': 'Max_Torque'}, inplace=True)

# %%
data1.head()
# Out:
#                    Car_Name  Year  Selling_Price  Kms_Driven Fuel_Type  \
# 0             Maruti 800 AC  2007          60000       70000    Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000       50000    Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000      100000    Diesel
# 3    Datsun RediGO T Option  2017         250000       46000    Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000      141000    Diesel
#
#   Seller_Type Transmission  owner
# 0  Individual       Manual      0
# 1  Individual       Manual      0
# 2  Individual       Manual      0
# 3  Individual       Manual      0
# 4  Individual       Manual      1

# %%
data3['Car_Name'] = pd.concat([data3['Make'], data3['Model']], axis=1).apply(lambda x: ''.join(x), axis=1)

# %%
data3 = data3.drop('Make', axis=1)
data3 = data3.drop('Model', axis=1)

# %%
data3.head()
# Out:
#    Selling_Price  Year  Kms_Driven Fuel_Type Transmission   Location   Color  \
# 0         505000  2017       87150    Petrol       Manual       Pune    Grey
# 1         450000  2014       75000    Diesel       Manual   Ludhiana   White
# 2         220000  2011       67000    Petrol       Manual    Lucknow  Maroon
# 3         799000  2019       37500    Petrol       Manual  Mangalore     Red
# 4        1950000  2018       69000    Diesel       Manual     Mumbai    Grey
#
#    owner Seller_Type   Engine           Max Power              Max_Torque  \
# 0      0   Corporate  1198 cc   87 bhp @ 6000 rpm       109 Nm @ 4500 rpm
# 1      1  Individual  1248 cc   74 bhp @ 4000 rpm       190 Nm @ 2000 rpm
# 2      0  Individual  1197 cc   79 bhp @ 6000 rpm  112.7619 Nm @ 4000 rpm
# 3      0  Individual  1197 cc   82 bhp @ 6000 rpm       113 Nm @ 4200 rpm
# 4      0  Individual  2393 cc  148 bhp @ 3400 rpm       343 Nm @ 1400 rpm
#
# ...

# %%
Data= pd.concat([data,data1,data2,data3], ignore_index= True)

# %%
Data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       335000.0       559000.0       27000    Petrol
# 1      sx4  2013       475000.0       954000.0       43000    Diesel
# 2     ciaz  2017       725000.0       985000.0        6900    Petrol
# 3  wagon r  2011       285000.0       415000.0        5200    Petrol
# 4    swift  2014       460000.0       687000.0       42450    Diesel
#
#   Seller_Type Transmission  owner mileage  ... Max_Torque seats Location  \
# 0      Dealer       Manual      0     NaN  ...        NaN   NaN      NaN
# 1      Dealer       Manual      0     NaN  ...        NaN   NaN      NaN
# 2      Dealer       Manual      0     NaN  ...        NaN   NaN      NaN
# 3      Dealer       Manual      0     NaN  ...        NaN   NaN      NaN
# 4      Dealer       Manual      0     NaN  ...        NaN   NaN      NaN
#
#    Color Max Power Drivetrain Length Width  Height  Fuel Tank Capacity
# ...

# %%
Data.tail()
# Out:
#                                         Car_Name  Year  Selling_Price  \
# 14823              MahindraXUV500 W8 [2015-2017]  2016       850000.0
# 14824                        HyundaiEon D-Lite +  2014       275000.0
# 14825            FordFigo Duratec Petrol ZXI 1.2  2013       240000.0
# 14826   BMW5-Series 520d Luxury Line [2017-2019]  2018      4290000.0
# 14827  MahindraBolero Power Plus ZLX [2016-2019]  2017       670000.0
#
#        Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  owner  \
# 14823            NaN       90300    Diesel  Individual       Manual      0
# 14824            NaN       83000    Petrol  Individual       Manual      1
# 14825            NaN       73000    Petrol  Individual       Manual      0
# 14826            NaN       60474    Diesel  Individual    Automatic      0
# 14827            NaN       72000    Diesel  Individual       Manual      0
#
#       mileage  ...         Max_Torque seats    Location   Color  \
# ...

# %%
Data.shape
# Out:
# (14828, 22)

# %%
Data.isnull().sum()
# Out:
# Car_Name                  0
# Year                      0
# Selling_Price             0
# Present_Price         14527
# Kms_Driven                0
# Fuel_Type                 0
# Seller_Type               0
# Transmission              0
# owner                     0
# mileage                6921
# Engine                 4942
# max_power              6915
# Max_Torque             4943
# seats                  4926
# Location              12769
# Color                 12769
# Max Power             12849
# Drivetrain            12905
# Length                12833
# Width                 12833
# Height                12833
# Fuel Tank Capacity    12882
# dtype: int64

# %%
Data = Data.drop_duplicates()

# %%
Data.shape
# Out:
# (12859, 22)

# %%
Data.isnull().sum()
# Out:
# Car_Name                  0
# Year                      0
# Selling_Price             0
# Present_Price         12560
# Kms_Driven                0
# Fuel_Type                 0
# Seller_Type               0
# Transmission              0
# owner                     0
# mileage                6141
# Engine                 4162
# max_power              6138
# Max_Torque             4163
# seats                  4146
# Location              10800
# Color                 10800
# Max Power             10880
# Drivetrain            10936
# Length                10864
# Width                 10864
# Height                10864
# Fuel Tank Capacity    10913
# dtype: int64

# %%
Data=Data.replace("NAN",np.nan)
Data.replace("?",np.nan,inplace=True)
Data.replace("???",np.nan,inplace=True)
Data.replace("MISSINGVALUE",np.nan,inplace=True)
Data.replace("MISSEDDATA",np.nan,inplace=True)

# %%
missing_train = Data.isnull().sum(axis=0).reset_index()
missing_train.columns = ['variable', 'missing values']
missing_train['filling factor (%)']=(Data.shape[0]-missing_train['missing values'])/Data.shape[0]*100
missing_train.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#               variable  missing values  filling factor (%)
# 0        Present_Price           12560            2.325220
# 1           Drivetrain           10936           14.954507
# 2   Fuel Tank Capacity           10913           15.133370
# 3            Max Power           10880           15.389999
# 4                Width           10864           15.514426
# 5               Length           10864           15.514426
# 6               Height           10864           15.514426
# 7                Color           10800           16.012132
# 8             Location           10800           16.012132
# 9              mileage            6141           52.243565
# 10           max_power            6138           52.266895
# 11          Max_Torque            4163           67.625787
# 12              Engine            4162           67.633564
# 13               seats            4146           67.757991
# 14        Transmission               0          100.000000
# ...

# %%
Data1= Data.drop(['Location','Drivetrain','Length','Width','Height','Fuel Tank Capacity','max_power','Max Power','Color'], axis=1)

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12859 entries, 0 to 14827
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       12859 non-null  object
#  1   Year           12859 non-null  int64
#  2   Selling_Price  12859 non-null  float64
#  3   Present_Price  299 non-null    float64
#  4   Kms_Driven     12859 non-null  int64
#  5   Fuel_Type      12859 non-null  object
#  6   Seller_Type    12859 non-null  object
#  7   Transmission   12859 non-null  object
#  8   owner          12859 non-null  int64
#  9   mileage        6718 non-null   object
#  10  Engine         8697 non-null   object
#  11  Max_Torque     8696 non-null   object
#  12  seats          8713 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.4+ MB

# %%
Data1.isnull().sum()
# Out:
# Car_Name             0
# Year                 0
# Selling_Price        0
# Present_Price    12560
# Kms_Driven           0
# Fuel_Type            0
# Seller_Type          0
# Transmission         0
# owner                0
# mileage           6141
# Engine            4162
# Max_Torque        4163
# seats             4146
# dtype: int64

# %%
Data1.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014       335000.0       559000.0       27000    Petrol
# 1            sx4  2013       475000.0       954000.0       43000    Diesel
# 2           ciaz  2017       725000.0       985000.0        6900    Petrol
# 3        wagon r  2011       285000.0       415000.0        5200    Petrol
# 4          swift  2014       460000.0       687000.0       42450    Diesel
# 5  vitara brezza  2018       925000.0       983000.0        2071    Diesel
# 6           ciaz  2015       675000.0       812000.0       18796    Petrol
# 7        s cross  2015       650000.0       861000.0       33429    Diesel
# 8           ciaz  2016       875000.0       889000.0       20273    Diesel
# 9           ciaz  2015       745000.0       892000.0       42367    Diesel
#
#   Seller_Type Transmission  owner mileage Engine Max_Torque  seats
# 0      Dealer       Manual      0     NaN    NaN        NaN    NaN
# ...

# %%
Data1.tail()
# Out:
#                                         Car_Name  Year  Selling_Price  \
# 14823              MahindraXUV500 W8 [2015-2017]  2016       850000.0
# 14824                        HyundaiEon D-Lite +  2014       275000.0
# 14825            FordFigo Duratec Petrol ZXI 1.2  2013       240000.0
# 14826   BMW5-Series 520d Luxury Line [2017-2019]  2018      4290000.0
# 14827  MahindraBolero Power Plus ZLX [2016-2019]  2017       670000.0
#
#        Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  owner  \
# 14823            NaN       90300    Diesel  Individual       Manual      0
# 14824            NaN       83000    Petrol  Individual       Manual      1
# 14825            NaN       73000    Petrol  Individual       Manual      0
# 14826            NaN       60474    Diesel  Individual    Automatic      0
# 14827            NaN       72000    Diesel  Individual       Manual      0
#
#       mileage   Engine         Max_Torque  seats
# ...

# %%
Data1['Present_Price']=pd.to_numeric(Data1['Present_Price'])
ORHP_mean_value=Data1['Present_Price'].mean()
Data1['Present_Price'].fillna(value=ORHP_mean_value, inplace=True)

# %%
Data1.isnull().sum()
# Out:
# Car_Name            0
# Year                0
# Selling_Price       0
# Present_Price       0
# Kms_Driven          0
# Fuel_Type           0
# Seller_Type         0
# Transmission        0
# owner               0
# mileage          6141
# Engine           4162
# Max_Torque       4163
# seats            4146
# dtype: int64

# %%
Data1.tail()
# Out:
#                                         Car_Name  Year  Selling_Price  \
# 14823              MahindraXUV500 W8 [2015-2017]  2016       850000.0
# 14824                        HyundaiEon D-Lite +  2014       275000.0
# 14825            FordFigo Duratec Petrol ZXI 1.2  2013       240000.0
# 14826   BMW5-Series 520d Luxury Line [2017-2019]  2018      4290000.0
# 14827  MahindraBolero Power Plus ZLX [2016-2019]  2017       670000.0
#
#        Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  owner  \
# 14823   754103.67893       90300    Diesel  Individual       Manual      0
# 14824   754103.67893       83000    Petrol  Individual       Manual      1
# 14825   754103.67893       73000    Petrol  Individual       Manual      0
# 14826   754103.67893       60474    Diesel  Individual    Automatic      0
# 14827   754103.67893       72000    Diesel  Individual       Manual      0
#
#       mileage   Engine         Max_Torque  seats
# ...

# %%
Data1[['engine', 'cc']] = Data1['Engine'].str.split(' ', n=1, expand=True)
Data1 = Data1.drop('Engine', axis=1)
Data1 = Data1.drop('cc', axis=1)

# %%
Data1[['Mileage', 'cc']] = Data1['mileage'].str.split(' ', n=1, expand=True)
Data1 = Data1.drop('mileage', axis=1)
Data1 = Data1.drop('cc', axis=1)

# %%
Data1.tail()
# Out:
#                                         Car_Name  Year  Selling_Price  \
# 14823              MahindraXUV500 W8 [2015-2017]  2016       850000.0
# 14824                        HyundaiEon D-Lite +  2014       275000.0
# 14825            FordFigo Duratec Petrol ZXI 1.2  2013       240000.0
# 14826   BMW5-Series 520d Luxury Line [2017-2019]  2018      4290000.0
# 14827  MahindraBolero Power Plus ZLX [2016-2019]  2017       670000.0
#
#        Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  owner  \
# 14823   754103.67893       90300    Diesel  Individual       Manual      0
# 14824   754103.67893       83000    Petrol  Individual       Manual      1
# 14825   754103.67893       73000    Petrol  Individual       Manual      0
# 14826   754103.67893       60474    Diesel  Individual    Automatic      0
# 14827   754103.67893       72000    Diesel  Individual       Manual      0
#
#               Max_Torque  seats engine Mileage
# ...

# %%
corr_matrix = Data1.corr()

# %%
print(corr_matrix)
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     owner  \
# Year           1.000000       0.345486      -0.005668   -0.385861 -0.433308
# Selling_Price  0.345486       1.000000       0.057122   -0.154462 -0.105322
# Present_Price -0.005668       0.057122       1.000000    0.021906  0.000483
# Kms_Driven    -0.385861      -0.154462       0.021906    1.000000  0.240533
# owner         -0.433308      -0.105322       0.000483    0.240533  1.000000
# seats         -0.000253       0.014124            NaN    0.196962  0.020135
#
#                   seats
# Year          -0.000253
# Selling_Price  0.014124
# Present_Price       NaN
# Kms_Driven     0.196962
# owner          0.020135
# seats          1.000000

# %%
Data1[['Nm', 'Torque']] = Data1['Max_Torque'].str.split('@', n=1, expand=True)

# %%
Data1.tail()
# Out:
#                                         Car_Name  Year  Selling_Price  \
# 14823              MahindraXUV500 W8 [2015-2017]  2016       850000.0
# 14824                        HyundaiEon D-Lite +  2014       275000.0
# 14825            FordFigo Duratec Petrol ZXI 1.2  2013       240000.0
# 14826   BMW5-Series 520d Luxury Line [2017-2019]  2018      4290000.0
# 14827  MahindraBolero Power Plus ZLX [2016-2019]  2017       670000.0
#
#        Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  owner  \
# 14823   754103.67893       90300    Diesel  Individual       Manual      0
# 14824   754103.67893       83000    Petrol  Individual       Manual      1
# 14825   754103.67893       73000    Petrol  Individual       Manual      0
# 14826   754103.67893       60474    Diesel  Individual    Automatic      0
# 14827   754103.67893       72000    Diesel  Individual       Manual      0
#
#               Max_Torque  seats engine Mileage       Nm     Torque
# ...

# %%
Data1 = Data1.drop('Nm', axis=1)
Data1 = Data1.drop('Max_Torque', axis=1)

# %%
Data1.head(30)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014       335000.0       559000.0       27000    Petrol
# 1             sx4  2013       475000.0       954000.0       43000    Diesel
# 2            ciaz  2017       725000.0       985000.0        6900    Petrol
# 3         wagon r  2011       285000.0       415000.0        5200    Petrol
# 4           swift  2014       460000.0       687000.0       42450    Diesel
# 5   vitara brezza  2018       925000.0       983000.0        2071    Diesel
# 6            ciaz  2015       675000.0       812000.0       18796    Petrol
# 7         s cross  2015       650000.0       861000.0       33429    Diesel
# 8            ciaz  2016       875000.0       889000.0       20273    Diesel
# 9            ciaz  2015       745000.0       892000.0       42367    Diesel
# 10       alto 800  2017       285000.0       360000.0        2135    Petrol
# ...

# %%
Data1['Torque'] = pd.to_numeric(Data1['Torque'], errors='coerce')
Data1['Mileage'] = pd.to_numeric(Data1['Mileage'], errors='coerce')
Data1['engine'] = pd.to_numeric(Data1['engine'], errors='coerce')

# %%
Data1['Torque'].fillna(Data1['Torque'].mean(),inplace=True)
Data1['seats'].fillna(Data1['seats'].mean(),inplace=True)
Data1['engine'].fillna(Data1['engine'].mean(),inplace=True)
Data1['Mileage'].fillna(Data1['Mileage'].median(),inplace=True)

# %%
Data1.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# owner            0
# seats            0
# engine           0
# Mileage          0
# Torque           0
# dtype: int64

# %%
Data1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       335000.0       559000.0       27000    Petrol
# 1      sx4  2013       475000.0       954000.0       43000    Diesel
# 2     ciaz  2017       725000.0       985000.0        6900    Petrol
# 3  wagon r  2011       285000.0       415000.0        5200    Petrol
# 4    swift  2014       460000.0       687000.0       42450    Diesel
#
#   Seller_Type Transmission  owner     seats       engine  Mileage  Torque
# 0      Dealer       Manual      0  5.405257  1490.437507    19.44  3025.0
# 1      Dealer       Manual      0  5.405257  1490.437507    19.44  3025.0
# 2      Dealer       Manual      0  5.405257  1490.437507    19.44  3025.0
# 3      Dealer       Manual      0  5.405257  1490.437507    19.44  3025.0
# 4      Dealer       Manual      0  5.405257  1490.437507    19.44  3025.0

# %%
Data1.tail()
# Out:
#                                         Car_Name  Year  Selling_Price  \
# 14823              MahindraXUV500 W8 [2015-2017]  2016       850000.0
# 14824                        HyundaiEon D-Lite +  2014       275000.0
# 14825            FordFigo Duratec Petrol ZXI 1.2  2013       240000.0
# 14826   BMW5-Series 520d Luxury Line [2017-2019]  2018      4290000.0
# 14827  MahindraBolero Power Plus ZLX [2016-2019]  2017       670000.0
#
#        Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  owner  \
# 14823   754103.67893       90300    Diesel  Individual       Manual      0
# 14824   754103.67893       83000    Petrol  Individual       Manual      1
# 14825   754103.67893       73000    Petrol  Individual       Manual      0
# 14826   754103.67893       60474    Diesel  Individual    Automatic      0
# 14827   754103.67893       72000    Diesel  Individual       Manual      0
#
#        seats  engine  Mileage  Torque
# 14823    7.0  2179.0    19.44  3025.0
# ...

# %%
plt.figure (figsize = (2 , 8) , dpi = 100)
heatmap = sns.heatmap (data.corr()[['Selling_Price']].sort_values (by = 'Selling_Price', ascending = False), vmin = -1, vmax = 1, annot = True, cmap = 'coolwarm')
heatmap.set_title ('Features Correlating with Price', fontdict = {'fontsize':16} , pad = 18);

# %%
corrmat = Data1.corr()
top_cor_features=corrmat.index
plt.figure(figsize=(20,9))
HM=sns.heatmap(Data1[top_cor_features].corr(),annot=True,cmap="BrBG")
HM.set_title('Correlation Heatmap of Car Data', fontdict={'fontsize':18}, pad=12);

# %%
Data1.describe()
# Out:
#                Year  Selling_Price  Present_Price    Kms_Driven         owner  \
# count  12859.000000   1.285900e+04   1.285900e+04  1.285900e+04  12859.000000
# mean    2013.778365   6.937178e+05   7.541037e+05  6.864570e+04      0.482386
# std        4.167275   1.164155e+06   1.304353e+05  5.565153e+04      0.780097
# min     1983.000000   1.000000e+04   3.200000e+04  0.000000e+00      0.000000
# 25%     2011.000000   2.500000e+05   7.541037e+05  3.500000e+04      0.000000
# 50%     2014.000000   4.349990e+05   7.541037e+05  6.000000e+04      0.000000
# 75%     2017.000000   7.000000e+05   7.541037e+05  9.000000e+04      1.000000
# max     2022.000000   3.500000e+07   9.260000e+06  2.360457e+06      5.000000
#
#               seats        engine       Mileage        Torque
# count  12859.000000  12859.000000  12859.000000  12859.000000
# mean       5.405257   1490.437507     19.453223   3025.000000
# std        0.782848    446.220076      2.926637    112.837696
# ...

# %%
Data1.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# owner              int64
# seats            float64
# engine           float64
# Mileage          float64
# Torque           float64
# dtype: object

# %%
mapping = {}
for i, category in enumerate(Data1['Fuel_Type'].unique()):
    mapping[category] = i

Data1['Fuel_Type'] = Data1['Fuel_Type'].map(mapping)


mapping = {}
for i, category in enumerate(Data1['Seller_Type'].unique()):
    mapping[category] = i

Data1['Seller_Type'] = Data1['Seller_Type'].map(mapping)

mapping = {}
for i, category in enumerate(Data1['Transmission'].unique()):
    mapping[category] = i

Data1['Transmission'] = Data1['Transmission'].map(mapping)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Data1['Car_Name']= le.fit_transform(Data1['Car_Name'])

# %%
# creating a class for Lasso Regression

class Lasso_Regression():

  #initiating the hyperparameters
  def __init__(self, learning_rate, no_of_iterations, lambda_parameter):

    self.learning_rate = learning_rate
    self.no_of_iterations = no_of_iterations
    self.lambda_parameter = lambda_parameter


  # fitting the dataset to the Lasso Regression model
  def fit(self, X, Y):

    # m --> number of Data points --> number of rows
    # n --> number of input features --> number of columns
    self.m, self.n = X.shape

    self.w = np.zeros(self.n)

    self.b = 0

    self.X = X

    self.Y = Y

    # implementing Gradient Descent algorithm for Optimization

    for i in range(self.no_of_iterations):     # missed "self"
      self.upadte_weights()


  # function for updating the weight & bias value
  def upadte_weights(self):

    # linear equation of the model
    Y_prediction = self.predict(self.X)

    # gradients (dw, db)

    # gradient for weight
    dw = np.zeros(self.n)

    for i in range(self.n):

      if self.w[i]>0:

        dw[i] = (-(2*(self.X[:,i]).dot(self.Y - Y_prediction)) + self.lambda_parameter) / self.m 

      else :

        dw[i] = (-(2*(self.X[:,i]).dot(self.Y - Y_prediction)) - self.lambda_parameter) / self.m


    # gradient for bias
    db = - 2 * np.sum(self.Y - Y_prediction) / self.m


    # updating the weights & bias

    self.w = self.w - self.learning_rate*dw
    self.b = self.b - self.learning_rate*db

    


  # Predicting the Target variable
  def predict(self,X):

    return X.dot(self.w) + self.b

# %%
import numpy as np

# Generate some random data
np.random.seed(0)
X = np.random.randn(100, 5)
y = X[:, 0] + 2 * X[:, 1] + np.random.randn(100)

# %%
# Split the data into training and test sets
X_train, X_test = X[:80], X[80:]
y_train, y_test = y[:80], y[80:]

# %%
# Fit the model
model = Lasso_Regression(learning_rate = 0.01, no_of_iterations=1000,
                         lambda_parameter=10)
model.fit(X_train, y_train)

# %%
test_data_prediction = model.predict(X_test)

# %%
# Evaluate the model on the test set
y_pred = model.predict(X_test)
error = np.mean((y_test - y_pred) ** 2)
print("Test MSE:", error)
# Out:
# Test MSE: 0.9290611664235762

# %%
total_sum_squares = np.sum((y_test - np.mean (y_test))**2)
residual_sum_squares = np.sum((y_test - y_pred)**2)
r_squared = 1 - (residual_sum_squares / total_sum_squares)

# %%
# Print results
print ("Mean Squared Error:" , error)
print ("R-squared score:",r_squared)
# Out:
# Mean Squared Error: 0.9290611664235762
# R-squared score: 0.839367437116256
